# %% [markdown]
# # Блок №4 Сравнение средних значений (t-test)

# %% [markdown]
# # Задание 1
# ___
# Укажите одно или несколько верных высказываний:
# + t-распределение всегда содержит только 20 или меньше наблюдений.
# + При достаточно большом числе степеней свободы (df >30) t-распределение постепенно начинает приближаться к нормальному распределению.
# + t-распределение имеет две моды при любом числе степеней свободы.
# + В случае t-распределения с df=15 в диапазоне среднее ± 2 стандартных отклонения лежит приблизительно 99% наблюдений.

# %% [markdown]
# Ответ:
# + При достаточно большом числе степеней свободы (df >30) t-распределение постепенно начинает приближаться к нормальному распределению.

# %% [markdown]
# # Задание 2
# ___
# Если на выборке в 15 наблюдений при помощи одновыборочного t-теста проверяется нулевая гипотеза: $\mu=10$
#
# и рассчитанное t-значение равняется $-2$ $(t = -2)$, то p-уровень значимости (двусторонний)﻿ равен:

# %% [markdown]
# Ответ:
# + 0,065

# %% [markdown]
# # Задание 3
# ___
# В первом эксперименте для сравнения двух средних $\bar{X_{1}}=17$, $\bar{X_{2}}=16$  применялся t-критерий Стьюдента, и эти различия оказались значимы (p = 0, 001). Во втором исследовании, также при помощи t - критерия, сравнивались два средних $\bar{X_{1}}=17$, $\bar{X_{2}}=36$, и эти различия не значимы при p = 0,8. В чем может быть причина таких результатов?
#
# Варианты ответов:
# + Возможно, во втором эксперименте больше объем выборок и меньше изменчивость исследуемого признака
# + Ни размер выборки, ни изменчивость исследуемого признака не может быть причиной таких результатов
# + Возможно, в первом эксперименте больше объем выборок и меньше изменчивость исследуемого признака

# %%
import numpy as np

import seaborn as sns

# %%
# Формируем выборки из нормального распределения
x1 = np.random.normal(loc=16, scale=0.2, size=100)
x2 = np.random.normal(loc=17, scale=0.2, size=100)

# %%
sns.distplot(x1)
sns.distplot(x2);
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Формируем выборки из нормального распределения
x1 = np.random.normal(loc=17, scale=10, size=10)
x2 = np.random.normal(loc=36, scale=10, size=10)

# %%
sns.distplot(x1)
sns.distplot(x2);
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Формируем выборки из нормального распределения
x1 = np.random.normal(loc=17, scale=0.2, size=100)
x2 = np.random.normal(loc=36, scale=0.2, size=100)

sns.distplot(x1)
sns.distplot(x2);
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Ответ:
# + Возможно, в первом эксперименте больше объем выборок и меньше изменчивость исследуемого признака

# %% [markdown]
# # Задание 4
# ___
# Ваш друг Ярослав изучает статистику и недавно прочитал статью, в которой исследовались различия между средними значениями числа рибосом двух различных типов бактерий. Ярослав просит Вас объяснить ему, что означает высказывание: "95% доверительный интервал для разности между средними значениями рибосом двух типов бактерий $\mu_{тип№1} -\mu_{тип№2}$ оказался равен от 100 до 300”.
#
# Варианты ответов:
# + Число рибосом у первого типа бактерий в среднем на 100-300 рибосом превышает число рибосом у второго типа.
# + Эти данные не позволяют отклонить нулевую гипотезу о равенстве средних значений μtype1 = μtype2.
# + Среднее значение числа рибосом у первого типа бактерий равняется 100, а у второго 300.
# + Число рибосом у второго типа бактерий в среднем на 100-300 рибосом превышает число рибосом у первого типа.

# %% [markdown]
# Ответ:
# + Число рибосом у первого типа бактерий в среднем на 100-300 рибосом превышает число рибосом у второго типа.

# %% [markdown]
# # Задание 5
# ___
# Знание t-распределения поможет нам корректно рассчитать границы доверительного интервала, особенно в тех случаях, если число наблюдений меньше 30. Ранее при расчете 95% доверительного интервала мы использовали формулу $\bar{x}\pm 1,96*\frac{sd_{x}}{\sqrt{n}}$
#
# Однако 95% всех наблюдений в случае t-распределения могут лежать в более широком диапазоне. Рассчитайте доверительный интервал основываясь на знании t - распределения для среднего значения температуры плавления ДНК у первого вида: $\bar{X}=89,9\quad sd=11,3\quad n=20$
#
# Для этого определите, в каком диапазоне находится 95% наблюдений у соответствующего t-распределения (df = n - 1) и используйте это значение вместо коэффициента 1.96.
#
# Для этого воспользуемся [таблицей](http://www.medcalc.org/manual/t-distribution.php) критических значений для t-распределения для нахождения нужного t-значения. В этой таблице нас интересует столбец, где A=0.95 (область под кривой). На пересечении этого столбца и строки с нужным числом степеней свободы и находится интересующее нас значение.

# %%
mu = 89.9
sd = 11.3
n = 20

df = n - 1
coev = 2.093

# %%
mu + coev * sd / n ** 0.5
# Out:
# 95.18850201290499

# %%
mu - coev * sd / n ** 0.5
# Out:
# 84.61149798709502

# %% [markdown]
# Ответ:
# [84,61 ; 95,19]

# %% [markdown]
# # Задание 6
# ___
# Первые премии Оскар за лучшую мужскую и женскую роль были вручены в 1929. Данные гистограммы демонстрируют распределение возраста победителей с 1929 по 2014 год (100 мужчин, 100 женщин). Используя t-критерий, проверьте, можно ли считать наблюдаемые различия в возрасте между лучшими актрисами и актерами  статистически достоверными.
#
# Средний возраст мужчин равен 45, sd = 9.
#
# Средний возраст женщин равен 34, sd = 10.
# ![](https://storage.yandexcloud.net/klms-public/production/learning-content/11/79/616/1777/8158/image.png)
#
# Рассчитав t-значение, вы можете сравнить его с [табличным](http://www.medcalc.org/manual/t-distribution.php), чтоб принять статистическое решение: отклонять ли нулевую гипотезу. Опять же, обратимся к таблице t-значений, как и в предыдущем задании найдем критическое значение для нашего эксперимента (на пересечении строки c нужным числом степеней свободы  и столбца, где P=0.05).  Если рассчитанное вами t-значение больше табличного: отклоняем нулевую гипотезу при p < 0.05.
#
# [Сайт](https://vavilovva.shinyapps.io/dist_calc/), где можно рассчитывать площадь под кривой в ситуации различных распределений и с различным числом степеней свободыx

# %%
import scipy.stats as ss

# %%
men = np.random.normal(loc=45, scale=9, size=100)
women = np.random.normal(loc=34, scale=10, size=100)

# %%
# Посмотрим на результаты t-test
ss.ttest_ind(men, women)
# Out:
# Ttest_indResult(statistic=6.685022476178166, pvalue=2.2968888572960358e-10)

# %% [markdown]
# Ответ: Отклоняем нулевую гипотезу о равенстве средних (p<0,05)

# %% [markdown]
# # Задание 7
# ___
# При помощи t-критерия можно исследовать взаимосвязь таких двух переменных как: (то есть в каких случаях мы сможем сформировать две выборки и сравнить два средних интересующего нас показателя между собой, таким образом, одна переменная будет разделять участников исследования на две группы, а среднее значение второй переменной будет рассчитываться в каждой из групп)
#
# Варанты ответ:
# + пол и группа крови человека
# + уровень образования (высшее, среднее) и месячный доход
# + пол и рост человека
# + пол и вес человека

# %% [markdown]
# Ответ:
# + уровень образования (высшее, среднее) и месячный доход
# + пол и рост человека
# + пол и вес человека

# %% [markdown]
# # Задание 8
# ___
# Соотнесите графики QQ-plot и гистограммы частот:
# ![](https://storage.yandexcloud.net/klms-public/production/learning-content/11/79/616/1777/8160/image.png)

# %% [markdown]
# Ответ:
# + Б -> 4
# + Г -> 3
# + В -> 2
# + А -> 1

# %% [markdown]
# # Задание 9
# ___
# Если для проверки нормальности распределения на выборке в 100 наблюдений мы применили критерий Шапиро-Уилка и получили p-уровень значимости, равный 0.001, то:
# + Распределение значимо отклоняется от нормального
# + Распределение можно считать нормальным
# + Распределение является бимодальным

# %% [markdown]
# Ответ:
# + Распределение значимо отклоняется от нормального

# %% [markdown]
# # Задание 10
# ___
# На графике представлены результаты трех экспериментов. В каждом эксперименте при помощи критерия t-Стьюдента сравнивались две группы А и В (по 30 наблюдений в каждой). В одном из экспериментов были получены статистически значимые различия (t = 12, p<0.05, df=58).
# ![](https://storage.yandexcloud.net/klms-public/production/learning-content/11/79/616/1777/8162/image.png)
#
# Варианты ответов:
# + Вероятнее всего, значимые различия получены в эксперименте №2
# + Вероятнее всего, значимые различия получены в эксперименте №1
# + Вероятнее всего, значимые различия получены в эксперименте №3

# %% [markdown]
# Ответ:
# + Вероятнее всего, значимые различия получены в эксперименте №1

# %% [markdown]
# # Задание 11
# ___
# Укажите верные высказывания:
# + Важно проверять распределение на нормальность, т.к. выбросы могут оказать значительное влияние на результаты t-теста
# + Непараметрический U-критерий Манна -Уитни не столь чувствителен к наличию выбросов по сравнению с t-тестом
# + Если распределение исследуемого признака значимо отличается от нормального только в одной группе, это не может отрицательно повлиять на результаты t - теста
# + Если в обеих группах распределение исследуемого признака значимо отклоняется от нормального, то t-тест всегда будет выдавать статистически значимые различия (p<0,05).

# %% [markdown]
# Ответ:
# + Важно проверять распределение на нормальность, т.к. выбросы могут оказать значительное влияние на результаты t-теста
# + Непараметрический U-критерий Манна -Уитни не столь чувствителен к наличию выбросов по сравнению с t-тестом
